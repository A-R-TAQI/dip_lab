# %% [markdown]
# <a href="https://colab.research.google.com/github/A-R-TAQI/dip_lab/blob/main/dip_lab_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/drive/MyDrive/dip_lab/clrpncl.jfif', 0)

# Perform Fourier Transform
fft = np.fft.fft2(image)
fft_shift = np.fft.fftshift(fft)

# Visualize the frequency spectrum
magnitude_spectrum1 = 20 * np.log(np.abs(fft_shift))

plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude_spectrum1, cmap='gray')
plt.title('Magnitude Spectrum1'), plt.xticks([]), plt.yticks([])
plt.show()

# Apply a high-pass filter in the frequency domain
rows, cols = image.shape
crow, ccol = rows // 2, cols // 2
fft_shift[crow - 30: crow + 30, ccol - 30: ccol + 30] = 0

# Perform Inverse Fourier Transform
fft_ishift = np.fft.ifftshift(fft_shift)
image_filtered = np.fft.ifft2(fft_ishift)
image_filtered = np.abs(image_filtered)

# Display the filtered image
plt.imshow(image_filtered, cmap='gray')
plt.title('Filtered Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/drive/MyDrive/dip_lab/clrwhel.jfif', 0)

# Perform Fourier Transform
fft = np.fft.fft2(image)
fft_shift = np.fft.fftshift(fft)

# Visualize the frequency spectrum
magnitude_spectrum = 20 * np.log(np.abs(fft_shift))

plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# Apply a high-pass filter in the frequency domain
rows, cols = image.shape
crow, ccol = rows // 2, cols // 2
fft_shift[crow - 30: crow + 30, ccol - 30: ccol + 30] = 0

# Perform Inverse Fourier Transform
fft_ishift = np.fft.ifftshift(fft_shift)
image_filtered = np.fft.ifft2(fft_ishift)
image_filtered = np.abs(image_filtered)

# Display the filtered image
plt.imshow(image_filtered, cmap='gray')
plt.title('Filtered Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
from PIL import Image
from numpy import asarray
import numpy as np

import pandas as pd
numpydata= asarray(magnitude_spectrum)
print(numpydata)
print("next output")
numpydata1=asarray(magnitude_spectrum1)
print(numpydata1)

# convert array into dataframe
DF = pd.DataFrame(numpydata)

# save the dataframe as a csv file
DF.to_csv("/content/drive/MyDrive/dip_lab/data1.csv")
# Out:
# [[146.71285287 139.22764915 161.51659042 ... 139.1070168  119.4034857
#   147.09006339]
#  [150.68015071 156.33500773 139.23562268 ... 164.0056573  152.44289644
#   146.82912764]
#  [134.9026005  159.8823225  150.56273029 ... 147.56163299 160.01312031
#   135.07894537]
#  ...
#  [134.9026005  135.07894537 160.01312031 ... 148.3833901  150.56273029
#   159.8823225 ]
#  [150.68015071 146.82912764 152.44289644 ... 159.87952265 139.23562268
#   156.33500773]
#  [146.71285287 147.09006339 119.4034857  ... 158.18835805 161.51659042
#   139.22764915]]
# next output
# [[116.9287755  133.25341376 133.67493671 ... 132.393348   133.67493671
#   133.25341376]
#  [117.61585175 123.73223273  75.24744269 ... 124.31942177 122.77309157
#   128.3527532 ]
#  [136.94787264 105.48535392  95.08713516 ... 130.01258643 128.52064752
#   120.08787805]
#  ...
#  [115.59941304 126.774827   131.50726256 ... 126.54902244 130.09142327
#   125.39158464]
# ...

# %%
import csv
f = open('/content/drive/MyDrive/dip_lab/data1.csv', 'rb')
reader = csv.reader(f)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image in grayscale
image = cv2.imread('/content/drive/MyDrive/dip_lab/colour.jfif', 0)

# Perform Fourier Transform
fft = np.fft.fft2(image)
fft_shift = np.fft.fftshift(fft)

# Visualize the frequency spectrum
magnitude_spectrum = 20 * np.log(np.abs(fft_shift))

plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()

# Apply a high-pass filter in the frequency domain
rows, cols = image.shape
crow, ccol = rows // 2, cols // 2
fft_shift[crow - 30: crow + 30, ccol - 30: ccol + 30] = 0

# Perform Inverse Fourier Transform
fft_ishift = np.fft.ifftshift(fft_shift)
image_filtered = np.fft.ifft2(fft_ishift)
image_filtered = np.abs(image_filtered)

# Display the filtered image
plt.imshow(image_filtered, cmap='gray')
plt.title('Filtered Image'), plt.xticks([]), plt.yticks([])
plt.show()
